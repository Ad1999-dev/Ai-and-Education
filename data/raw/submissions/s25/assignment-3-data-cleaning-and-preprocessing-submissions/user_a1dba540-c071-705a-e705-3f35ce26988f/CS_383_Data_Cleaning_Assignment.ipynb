# %% [markdown]
# How many late days are you using for this assignment?

# %%
"0"
# Out:
# '0'

# %%
# Imports and pip installations (if needed)
import pandas as pd 
import numpy as np
from IPython.display import display
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# # Part 1: Load the dataset

# %%
# Load the given datasets
categorical = pd.read_csv("chronic_kidney_disease_categorical.csv")
numerical = pd.read_csv("chronic_kidney_disease_numerical (2).csv")
# Print the data
display(categorical, numerical)
# Out:
#      unique_id   al   su       rbc        pc         pcc          ba  htn  \
# 0       224481  3.0  NaN       NaN       NaN  notpresent  notpresent  yes
# 1       992643  0.0  0.0       NaN       NaN  notpresent  notpresent   no
# 2       308740  1.0  0.0  abnormal  abnormal  notpresent  notpresent  yes
# 3       450314  1.0  0.0       NaN    normal  notpresent  notpresent   no
# 4       881763  0.0  0.0    normal    normal  notpresent  notpresent   no
# ..         ...  ...  ...       ...       ...         ...         ...  ...
# 425     769512  0.0  0.0    normal    normal  notpresent  notpresent   no
# 426     872034  2.0  1.0  abnormal  abnormal  notpresent     present  yes
# 427     643007  NaN  NaN       NaN    normal  notpresent  notpresent  yes
# 428     840392  NaN  NaN       NaN       NaN  notpresent  notpresent  yes
# 429     856244  0.0  0.0       NaN    normal  notpresent  notpresent  yes
#
#       dm  cad appet   pe  ane  Target
# 0    yes   no  good  yes   no     ckd
# 1     no   no  good   no   no  notckd
# 2     no   no  good  yes   no     ckd
# 3     no   no  good   no  yes     ckd
# 4     no   no  good   no   no  notckd
# ..   ...  ...   ...  ...  ...     ...
# 425   no   no  good   no   no  notckd
# 426  yes  yes  poor   no   no     ckd
# 427  yes  yes  poor   no   no     ckd
# 428   no   no  poor   no   no     ckd
# 429  yes   no  poor   no   no     ckd
#
# [430 rows x 14 columns]
#      unique_id   age     bp    bgr     bu   sc    sod  pot  hemo   pcv  \
# 0       203694  38.0   80.0   99.0   19.0  0.5  147.0  3.5  13.6  44.0
# 1       938027  43.0   60.0  108.0   25.0  1.0  144.0  5.0  17.8  43.0
# 2       421471  37.0   60.0  111.0   35.0  0.8  135.0  4.1  16.2  50.0
# 3       764115  70.0   90.0  144.0  125.0  4.0  136.0  4.6  12.0  37.0
# 4       240975  47.0   80.0   95.0   35.0  0.9  140.0  4.1   NaN   NaN
# ..         ...   ...    ...    ...    ...  ...    ...  ...   ...   ...
# 415     522912  56.0   80.0  165.0   55.0  1.8    NaN  NaN  13.5  40.0
# 416     475200  64.0  100.0  163.0   54.0  7.2  140.0  4.6   7.9  26.0
# 417     168242  48.0   60.0  112.0   44.0  1.2  142.0  4.9  14.5  44.0
# 418     474407  21.0   90.0  107.0   40.0  1.7  125.0  3.5   8.3  23.0
# 419     926033  50.0   70.0  230.0   50.0  2.2    NaN  NaN  12.0  41.0
#
#         wbcc  rbcc
# 0     7300.0   6.4
# 1     7200.0   5.5
# 2     5500.0   5.7
# 3     8200.0   4.5
# 4        NaN   NaN
# ..       ...   ...
# 415  11800.0   5.0
# 416   7500.0   3.4
# 417   9400.0   6.4
# 418  12400.0   3.9
# 419  10400.0   4.6
#
# [420 rows x 12 columns]

# %% [markdown]
# # Part 2: Analyze the Dataset

# %% [markdown]
# Refer to this: https://archive.ics.uci.edu/dataset/336/chronic+kidney+disease
#
# Explain what the each data is in your own words. What are the features and labels? Are the features in the given datasets : categorical, numerical or both? Give 3 examples of categorical and numerical columns each (if they exist)

# %% [markdown]
# Answer: The data provided in the link shows data collected from UC Irvine hospital over a 2 month period, with 24 different variables that contribute to predicting chronic kidney disease. In the given dataset, there is both numerical and categorical variables. 3 Categorical variables are specific gravity, albumin, and sugar. 3 Numerical variables are age, blood pressure, and blood glucose random.

# %% [markdown]
# # Part 3: Data Preprocessing
#
# A fundamental skill in Machine Learning is mastering the art of data cleaning and preprocessing. In this assignment, you will learn and apply essential data cleaning techniques to transform a raw dataset into a clean, ready-to-use form which you can use for regression or classification tasks. By the end of this assignment, you'll have a fully clean dataset and a solid foundation in preparing data for various machine learning models.

# %% [markdown]
# ## Part 3.1 : Drop Duplicate rows
#
# Let's start by checking if the given datasets have any duplicate rows (same Unique Id). Use pandas to identify and remove these duplicate rows from the given dataset

# %%
# For the numerical dataset, check if there are duplicate rows in the dataset. If yes, print total number of duplicate rows
duplicate_total = numerical.duplicated().sum()
print("Total number of Duplicate Rows in Numerical: ", duplicate_total)
# Drop these duplicate rows

numerical_nodupe = numerical.drop_duplicates(subset = ["unique_id"])
print("Dropped Duplicated IDs")
# Repeat the same for categorical dataset. Print the duplicate rows and drop them
duplicate_total2 = categorical.duplicated().sum()
print("Total number of Duplicate Rows in Categorical: ", duplicate_total2)

categorical_nodupe = categorical.drop_duplicates(subset = ["unique_id"])
print("Dropped Duplicated IDs")
# Out:
# Total number of Duplicate Rows in Numerical:  30
# Dropped Duplicated IDs
# Total number of Duplicate Rows in Categorical:  30
# Dropped Duplicated IDs

# %% [markdown]
# ## Part 3.2: Combine two differents datasets
#
# A good skill to have is to know how to combine 2 different datasets.
#
# Are all the unique ids are present in both datasets? Why do you think so? If not, what do the rows that are missing from one of the datasets look like in the combined table?

# %% [markdown]
# Answer:

# %%
# Merge the two given numerical and categorical datasets based on their unique_ID.
merged_ds = pd.merge(numerical_nodupe, categorical_nodupe, on = "unique_id", how="outer", indicator=True)
#Print the combined dataset
display(merged_ds)

missing_rows = merged_ds[merged_ds["_merge"] != "both"]
print("Missing rows: \n",missing_rows)

print("There are 10 pieces of data missing from the numerical dataset, but are present in the categorical dataset.\n When shown in the merged dataset table, they are shown as missing all values that are considered numerical, \nthat being age, bp, bgr, ect. They don't have any numerical values inputted, thus being left out of the numerical dataset since they're numerical values are all NaN.")
# Out:
#      unique_id   age    bp    bgr     bu    sc    sod  pot  hemo   pcv  ...  \
# 0       102677  59.0  70.0   76.0  186.0  15.0  135.0  7.6   7.1  22.0  ...
# 1       103570  24.0  80.0  125.0    NaN   NaN  136.0  3.5  15.4  43.0  ...
# 2       104675  65.0  80.0  215.0  133.0   2.5    NaN  NaN  13.2  41.0  ...
# 3       105923  90.0  90.0  139.0   89.0   3.0  140.0  4.1  12.0  37.0  ...
# 4       107297  60.0  70.0    NaN    NaN   NaN    NaN  NaN  16.4  43.0  ...
# ..         ...   ...   ...    ...    ...   ...    ...  ...   ...   ...  ...
# 395     995177  69.0  70.0  214.0   96.0   6.3  120.0  3.9   9.4  28.0  ...
# 396     996076  57.0  60.0  105.0   49.0   1.2  150.0  4.7  15.7  44.0  ...
# 397     996412  70.0  60.0  120.0   40.0   0.5  140.0  4.6  16.0  43.0  ...
# 398     997629  35.0   NaN   99.0   30.0   0.5  135.0  4.9  15.4  48.0  ...
# 399     997876  64.0  70.0  107.0   15.0   NaN    NaN  NaN  12.8  38.0  ...
#
#             pcc          ba  htn   dm  cad appet   pe  ane  Target _merge
# 0    notpresent  notpresent  yes   no   no  poor  yes  yes     ckd   both
# 1    notpresent  notpresent   no   no   no  good   no   no  notckd   both
# 2       present  notpresent   no  yes   no  good   no   no     ckd   both
# 3    notpresent  notpresent  yes  yes   no  good   no   no     ckd   both
# 4    notpresent  notpresent   no   no   no  good   no   no  notckd   both
# ..          ...         ...  ...  ...  ...   ...  ...  ...     ...    ...
# 395     present     present  yes  yes  yes  good  yes  yes     ckd   both
# 396  notpresent  notpresent   no   no   no  good   no   no  notckd   both
# 397  notpresent  notpresent   no   no   no  good   no   no  notckd   both
# 398         NaN         NaN   no   no   no  good   no   no  notckd   both
# 399  notpresent  notpresent   no   no   no  good   no   no     ckd   both
#
# [400 rows x 26 columns]
# Missing rows:
#       unique_id  age  bp  bgr  bu  sc  sod  pot  hemo  pcv  ...         pcc  \
# 47      208034  NaN NaN  NaN NaN NaN  NaN  NaN   NaN  NaN  ...  notpresent
# 58      240430  NaN NaN  NaN NaN NaN  NaN  NaN   NaN  NaN  ...         NaN
# 64      254775  NaN NaN  NaN NaN NaN  NaN  NaN   NaN  NaN  ...  notpresent
# 69      266335  NaN NaN  NaN NaN NaN  NaN  NaN   NaN  NaN  ...  notpresent
# 80      292312  NaN NaN  NaN NaN NaN  NaN  NaN   NaN  NaN  ...  notpresent
# 83      298297  NaN NaN  NaN NaN NaN  NaN  NaN   NaN  NaN  ...  notpresent
# 97      325238  NaN NaN  NaN NaN NaN  NaN  NaN   NaN  NaN  ...  notpresent
# 173     488947  NaN NaN  NaN NaN NaN  NaN  NaN   NaN  NaN  ...  notpresent
# 261     663387  NaN NaN  NaN NaN NaN  NaN  NaN   NaN  NaN  ...  notpresent
# 376     948317  NaN NaN  NaN NaN NaN  NaN  NaN   NaN  NaN  ...  notpresent
#
#              ba  htn   dm  cad appet   pe  ane  Target      _merge
# 47   notpresent  yes  yes  yes  good  yes   no     ckd  right_only
# 58          NaN   no   no   no  good   no   no  notckd  right_only
# 64   notpresent  yes  yes  yes  good   no  yes     ckd  right_only
# 69   notpresent   no   no   no  good   no   no  notckd  right_only
# 80   notpresent   no   no   no  good   no   no  notckd  right_only
# 83   notpresent   no   no   no  good   no   no  notckd  right_only
# 97   notpresent  yes  yes   no  poor   no  yes   ckd\t  right_only
# 173  notpresent   no   no   no  good   no   no     ckd  right_only
# 261  notpresent   no   no   no  poor   no  yes     ckd  right_only
# 376  notpresent   no   no   no  good   no   no  notckd  right_only
#
# [10 rows x 26 columns]
# There are 10 pieces of data missing from the numerical dataset, but are present in the categorical dataset.
#  When shown in the merged dataset table, they are shown as missing all values that are considered numerical,
# that being age, bp, bgr, ect. They don't have any numerical values inputted, thus being left out of the numerical dataset since they're numerical values are all NaN.

# %% [markdown]
# ## Part 3.3: Rows with Missing values
#
# Removing missing values from a dataset is important for classification because it ensures the model is trained on complete and accurate data, leading to better performance and reliable predictions. Incomplete data can introduce bias and errors, negatively impacting the model's effectiveness.

# %%
# Calculate the percentage of rows that contain atleast one missing value
missing_rows = merged_ds[merged_ds.isnull().any(axis=1)]
print("Rows with at least one missing value:", missing_rows.shape[0])

missing_data_percentage = (missing_rows.shape[0]/merged_ds.shape[0])*100

# Print %
print("Percentage of rows that contain atleast one missing value: ", missing_data_percentage, "%")
# Drop these rows from the dataset
merged_ds2 = merged_ds.dropna()
# Print the Dataset
display(merged_ds2)
# Out:
# Rows with at least one missing value: 247
# Percentage of rows that contain atleast one missing value:  61.75000000000001 %
#      unique_id   age    bp    bgr     bu    sc    sod  pot  hemo   pcv  ...  \
# 0       102677  59.0  70.0   76.0  186.0  15.0  135.0  7.6   7.1  22.0  ...
# 6       109053  64.0  60.0  106.0   27.0   0.7  150.0  3.3  14.4  42.0  ...
# 7       114717  41.0  80.0  122.0   25.0   0.8  138.0  5.0  17.1  41.0  ...
# 8       118191  42.0  70.0   93.0   32.0   0.9  143.0  4.7  16.6  43.0  ...
# 9       118596  74.0  60.0   88.0   50.0   0.6  147.0  3.7  17.2  53.0  ...
# ..         ...   ...   ...    ...    ...   ...    ...  ...   ...   ...  ...
# 390     980291  62.0  70.0  122.0   42.0   1.7  136.0  4.7  12.6  39.0  ...
# 391     991031  30.0  80.0   89.0   42.0   0.5  139.0  5.0  16.7  52.0  ...
# 394     994377  71.0  70.0   81.0   18.0   0.8  145.0  5.0  14.7  44.0  ...
# 395     995177  69.0  70.0  214.0   96.0   6.3  120.0  3.9   9.4  28.0  ...
# 396     996076  57.0  60.0  105.0   49.0   1.2  150.0  4.7  15.7  44.0  ...
#
#             pcc          ba  htn   dm  cad appet   pe  ane  Target _merge
# 0    notpresent  notpresent  yes   no   no  poor  yes  yes     ckd   both
# 6    notpresent  notpresent   no   no   no  good   no   no  notckd   both
# 7    notpresent  notpresent   no   no   no  good   no   no  notckd   both
# 8    notpresent  notpresent   no   no   no  good   no   no  notckd   both
# 9    notpresent  notpresent   no   no   no  good   no   no  notckd   both
# ..          ...         ...  ...  ...  ...   ...  ...  ...     ...    ...
# 390  notpresent  notpresent  yes  yes   no  good   no   no     ckd   both
# 391  notpresent  notpresent   no   no   no  good   no   no  notckd   both
# 394  notpresent  notpresent   no   no   no  good   no   no  notckd   both
# 395     present     present  yes  yes  yes  good  yes  yes     ckd   both
# 396  notpresent  notpresent   no   no   no  good   no   no  notckd   both
#
# [153 rows x 26 columns]

# %% [markdown]
# ## Part 3.4: Sort the dataset according to the Labels

# %%
# Sort the dataset according to the values in 'Target' column. Make sure reset the indices after sorting
merged_ds_sorted = merged_ds2.sort_values(by="Target").reset_index(drop=True)
# Print the dataset
display(merged_ds_sorted)
# Out:
#      unique_id   age    bp    bgr     bu    sc    sod  pot  hemo   pcv  ...  \
# 0       102677  59.0  70.0   76.0  186.0  15.0  135.0  7.6   7.1  22.0  ...
# 1       337834  48.0  70.0  117.0   56.0   3.8  111.0  2.5  11.2  32.0  ...
# 2       343710  61.0  80.0  173.0  148.0   3.9  135.0  5.2   7.7  24.0  ...
# 3       349892  59.0  70.0  424.0   55.0   1.7  138.0  4.5  12.6  37.0  ...
# 4       353025  40.0  70.0  253.0  150.0  11.9  132.0  5.6  10.9  31.0  ...
# ..         ...   ...   ...    ...    ...   ...    ...  ...   ...   ...  ...
# 148     486397  20.0  70.0  123.0   44.0   1.0  135.0  3.8  14.6  44.0  ...
# 149     203466  22.0  60.0   97.0   18.0   1.2  138.0  4.3  13.5  42.0  ...
# 150     482105  44.0  60.0   95.0   46.0   0.5  138.0  4.2  15.0  50.0  ...
# 151     228849  58.0  80.0  100.0   50.0   1.2  140.0  3.5  14.0  50.0  ...
# 152     996076  57.0  60.0  105.0   49.0   1.2  150.0  4.7  15.7  44.0  ...
#
#             pcc          ba  htn   dm  cad appet   pe  ane  Target _merge
# 0    notpresent  notpresent  yes   no   no  poor  yes  yes     ckd   both
# 1       present  notpresent  yes   no   no  poor  yes  yes     ckd   both
# 2    notpresent  notpresent  yes  yes  yes  poor  yes  yes     ckd   both
# 3    notpresent  notpresent  yes  yes  yes  good   no   no     ckd   both
# 4    notpresent  notpresent  yes  yes   no  poor  yes   no     ckd   both
# ..          ...         ...  ...  ...  ...   ...  ...  ...     ...    ...
# 148  notpresent  notpresent   no   no   no  good   no   no  notckd   both
# 149  notpresent  notpresent   no   no   no  good   no   no  notckd   both
# 150  notpresent  notpresent   no   no   no  good   no   no  notckd   both
# 151  notpresent  notpresent   no   no   no  good   no   no  notckd   both
# 152  notpresent  notpresent   no   no   no  good   no   no  notckd   both
#
# [153 rows x 26 columns]

# %% [markdown]
# ## Part 3.5: Encoding Categorical data
#
# In this step, we identify and process the categorical columns in the sorted dataset. We map each unique value in these columns to separate "dummy" columns.
#
# For example, the column 'rbc' will be transformed into two columns 'rbc_normal' and 'rbc_abnormal'. If a row's value in 'rbc' is 'normal', the 'rbc_normal' column will be set to 1 and 'rbc_abnormal' will be set to 0.
#
#
# **Note: Find a correct pandas function to do this **

# %%
# Write code here
categorical_columns = ['rbc', 'pc', 'pcc', 'ba', 'htn', 'dm', 'cad', 'appet', 'pe', 'ane', 'Target']
merged_ds_encoded = pd.get_dummies(merged_ds_sorted, columns=categorical_columns)

# Print the dataset
display(merged_ds_encoded)
# Out:
#      unique_id   age    bp    bgr     bu    sc    sod  pot  hemo   pcv  ...  \
# 0       102677  59.0  70.0   76.0  186.0  15.0  135.0  7.6   7.1  22.0  ...
# 1       337834  48.0  70.0  117.0   56.0   3.8  111.0  2.5  11.2  32.0  ...
# 2       343710  61.0  80.0  173.0  148.0   3.9  135.0  5.2   7.7  24.0  ...
# 3       349892  59.0  70.0  424.0   55.0   1.7  138.0  4.5  12.6  37.0  ...
# 4       353025  40.0  70.0  253.0  150.0  11.9  132.0  5.6  10.9  31.0  ...
# ..         ...   ...   ...    ...    ...   ...    ...  ...   ...   ...  ...
# 148     486397  20.0  70.0  123.0   44.0   1.0  135.0  3.8  14.6  44.0  ...
# 149     203466  22.0  60.0   97.0   18.0   1.2  138.0  4.3  13.5  42.0  ...
# 150     482105  44.0  60.0   95.0   46.0   0.5  138.0  4.2  15.0  50.0  ...
# 151     228849  58.0  80.0  100.0   50.0   1.2  140.0  3.5  14.0  50.0  ...
# 152     996076  57.0  60.0  105.0   49.0   1.2  150.0  4.7  15.7  44.0  ...
#
#      cad_no  cad_yes  appet_good  appet_poor  pe_no  pe_yes  ane_no  ane_yes  \
# 0      True    False       False        True  False    True   False     True
# 1      True    False       False        True  False    True   False     True
# 2     False     True       False        True  False    True   False     True
# 3     False     True        True       False   True   False    True    False
# 4      True    False       False        True  False    True    True    False
# ..      ...      ...         ...         ...    ...     ...     ...      ...
# 148    True    False        True       False   True   False    True    False
# 149    True    False        True       False   True   False    True    False
# 150    True    False        True       False   True   False    True    False
# 151    True    False        True       False   True   False    True    False
# 152    True    False        True       False   True   False    True    False
#
#      Target_ckd  Target_notckd
# 0          True          False
# 1          True          False
# 2          True          False
# 3          True          False
# 4          True          False
# ..          ...            ...
# 148       False           True
# 149       False           True
# 150       False           True
# 151       False           True
# 152       False           True
#
# [153 rows x 37 columns]

# %% [markdown]
# In the example we went through above, another solution is to have a single column for the binary variable. In the downstream modeling would this be equivalent? What effect would this have if the categorical variable could take more than 2 values? For example, let's say we have a categorical feature that is "type of condiment" that can take 5 separate values and we are trying to predict the rating of a particular sandwich.

# %% [markdown]
# Answer: For this example, I don't see why only using one column would affect our downstream modeling since the categorical values of this dataset are only "good" or "poor", or "yes" or "no". If the column for "pe_yes" is True for example, then "pe_no" will always be False, and thus could just be represented as one column. However, this changes if the categorical value could take more than 2 values. In that case, it would be beneficial to have them spread out in multiple columns so that each condiment, for example, would be processed independently to the other condiments, avoiding potential biased predictions due to the model treating the categories as ordinal. By breaking the condiments into 5 seperate columns, it would allow the model a clearer look at the data, and allow it to understand the relationship within the data to allow it to predict the rating of a sandwich more effecively.

# %% [markdown]
# ## Part 3.6 : Remove Outliers from Numerical Columns
#
# Outliers can disproportionately influence the fit of a regression model, potentially leading to a model that does not generalize well therefore it is important that we remove outliers from the numerical columns of the dataset.
#
# For this dataset, we define an outlier to be 3 times the standard deviation from the mean. Drop these outliers from the dataset

# %%
# Remove outliers
numerical_columns = ['age', 'bp', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hemo', 'pcv', 'wbcc', 'rbcc']

mean_vals = merged_ds_encoded[numerical_columns].mean()
std_vals = merged_ds_encoded[numerical_columns].std()

lower_bound = mean_vals - (3*std_vals)
upper_bound = mean_vals + (3*std_vals)

for col in numerical_columns:
    lower_bound[col] = max(0, lower_bound[col])

print(lower_bound, upper_bound)
filtered_ds = merged_ds_encoded.copy()
for col in numerical_columns:
    if any((filtered_ds[col] < lower_bound[col]) | (filtered_ds[col] > upper_bound[col])):
        filtered_ds = filtered_ds.drop(filtered_ds[(filtered_ds[col] < lower_bound[col]) | (filtered_ds[col] > upper_bound[col])].index)
        
# Print the dataset
display(filtered_ds)
# Out:
# age       2.598464
# bp       40.966650
# bgr       0.000000
# bu        0.000000
# sc        0.000000
# sod     116.126905
# pot       0.000000
# hemo      5.082753
# pcv      14.929232
# wbcc      0.000000
# rbcc      1.797915
# dtype: float64 age        96.146634
# bp        107.137926
# bgr       326.400023
# bu        195.374041
# sc         11.150143
# sod       161.389435
# pot        15.232840
# hemo       22.364305
# pcv        68.809330
# wbcc    17966.932771
# rbcc        7.975942
# dtype: float64
#      unique_id   age     bp    bgr     bu   sc    sod  pot  hemo   pcv  ...  \
# 2       343710  61.0   80.0  173.0  148.0  3.9  135.0  5.2   7.7  24.0  ...
# 5       397388  63.0  100.0  280.0   35.0  3.2  143.0  3.5  13.0  40.0  ...
# 7       438182  73.0   80.0  253.0  142.0  4.6  138.0  5.8  10.5  33.0  ...
# 8       474407  21.0   90.0  107.0   40.0  1.7  125.0  3.5   8.3  23.0  ...
# 9       475200  64.0  100.0  163.0   54.0  7.2  140.0  4.6   7.9  26.0  ...
# ..         ...   ...    ...    ...    ...  ...    ...  ...   ...   ...  ...
# 148     486397  20.0   70.0  123.0   44.0  1.0  135.0  3.8  14.6  44.0  ...
# 149     203466  22.0   60.0   97.0   18.0  1.2  138.0  4.3  13.5  42.0  ...
# 150     482105  44.0   60.0   95.0   46.0  0.5  138.0  4.2  15.0  50.0  ...
# 151     228849  58.0   80.0  100.0   50.0  1.2  140.0  3.5  14.0  50.0  ...
# 152     996076  57.0   60.0  105.0   49.0  1.2  150.0  4.7  15.7  44.0  ...
#
#      cad_no  cad_yes  appet_good  appet_poor  pe_no  pe_yes  ane_no  ane_yes  \
# 2     False     True       False        True  False    True   False     True
# 5     False     True        True       False   True   False    True    False
# 7     False     True        True       False   True   False    True    False
# 8      True    False        True       False   True   False   False     True
# 9      True    False        True       False  False    True    True    False
# ..      ...      ...         ...         ...    ...     ...     ...      ...
# 148    True    False        True       False   True   False    True    False
# 149    True    False        True       False   True   False    True    False
# 150    True    False        True       False   True   False    True    False
# 151    True    False        True       False   True   False    True    False
# 152    True    False        True       False   True   False    True    False
#
#      Target_ckd  Target_notckd
# 2          True          False
# 5          True          False
# 7          True          False
# 8          True          False
# 9          True          False
# ..          ...            ...
# 148       False           True
# 149       False           True
# 150       False           True
# 151       False           True
# 152       False           True
#
# [134 rows x 37 columns]

# %% [markdown]
# ## Part 3.7 : Normalize the Numerical Columns
#
# Normalizing numerical attributes ensures that all features contribute equally to the model by scaling them to a consistent range, which improves model performance and convergence. It prevents features with larger scales from disproportionately influencing the model's learning process.

# %%
# Normalize the all Numerical Attributes in the dataset.
normalized_ds = filtered_ds.copy()

scaler = MinMaxScaler()
normalized_ds[numerical_columns] = scaler.fit_transform(normalized_ds[numerical_columns])
# Print the dataset
display(normalized_ds)
# Out:
#      unique_id       age    bp       bgr        bu        sc       sod  \
# 2       343710  0.743243  0.50  0.442060  0.901961  0.432099  0.500000
# 5       397388  0.770270  1.00  0.901288  0.163399  0.345679  0.766667
# 7       438182  0.905405  0.50  0.785408  0.862745  0.518519  0.600000
# 8       474407  0.202703  0.75  0.158798  0.196078  0.160494  0.166667
# 9       475200  0.783784  1.00  0.399142  0.287582  0.839506  0.666667
# ..         ...       ...   ...       ...       ...       ...       ...
# 148     486397  0.189189  0.25  0.227468  0.222222  0.074074  0.500000
# 149     203466  0.216216  0.00  0.115880  0.052288  0.098765  0.600000
# 150     482105  0.513514  0.00  0.107296  0.235294  0.012346  0.600000
# 151     228849  0.702703  0.50  0.128755  0.261438  0.098765  0.666667
# 152     996076  0.689189  0.00  0.150215  0.254902  0.098765  1.000000
#
#           pot      hemo       pcv  ...  cad_no  cad_yes  appet_good  \
# 2    0.657143  0.172131  0.210526  ...   False     True       False
# 5    0.171429  0.606557  0.631579  ...   False     True        True
# 7    0.828571  0.401639  0.447368  ...   False     True        True
# 8    0.171429  0.221311  0.184211  ...    True    False        True
# 9    0.485714  0.188525  0.263158  ...    True    False        True
# ..        ...       ...       ...  ...     ...      ...         ...
# 148  0.257143  0.737705  0.736842  ...    True    False        True
# 149  0.400000  0.647541  0.684211  ...    True    False        True
# 150  0.371429  0.770492  0.894737  ...    True    False        True
# 151  0.171429  0.688525  0.894737  ...    True    False        True
# 152  0.514286  0.827869  0.736842  ...    True    False        True
#
#      appet_poor  pe_no  pe_yes  ane_no  ane_yes  Target_ckd  Target_notckd
# 2          True  False    True   False     True        True          False
# 5         False   True   False    True    False        True          False
# 7         False   True   False    True    False        True          False
# 8         False   True   False   False     True        True          False
# 9         False  False    True    True    False        True          False
# ..          ...    ...     ...     ...      ...         ...            ...
# 148       False   True   False    True    False       False           True
# 149       False   True   False    True    False       False           True
# 150       False   True   False    True    False       False           True
# 151       False   True   False    True    False       False           True
# 152       False   True   False    True    False       False           True
#
# [134 rows x 37 columns]

# %% [markdown]
# ## Part 3.8: Remove Unnecessary columns

# %% [markdown]
# Are there any columns in this dataset which are not appropriate for modeling and predictions? Which column(s)? Justify their exclusion and remove them

# %% [markdown]
# Answer: I believe that "Unique_ID", while useful for determining duplicated rows, no longer has a purpose and is not needed for modeling and predictions since it is just an arbitrary number. Additionally, I added a _Merge column back when I merged the datasets just to be able to tell what the lines that were present in one but not the other looked like, and I am also going to remove this one since I no longer have a use for it and it is not needed in modeling.

# %%
#Remove that column
normalized_ds = normalized_ds.drop(columns=["_merge","unique_id"])
# Print the dataset
display(normalized_ds)

# %% [markdown]
# ## Part 3.9: Export the Cleaned Data

# %% [markdown]
# Now that you've completed these cleaning steps you should have a pandas dataframe which is much cleaner and ready for modeling. Our final step is to save our work. Export the DataFrame to a two new formats: csv and json.

# %%
# Export the dataframe to a new csv file
new_dscsv = normalized_ds.to_csv("new_kidney_disease.csv", index=False)
# Export the dataframe to a new json file
new_dsjson = normalized_ds.to_json("new_kidney_disease.json", orient="records")

# %% [markdown]
# # Part 4: Data conversions with Large Language Models
#
# One powerful use case of ChatGPT (and other generative language models) is cleaning and transforming data. In some cases, these models can directly manipulate loosely structured data that you provide to them into a standard format. In the other cases, you can often prompt the model to create a conversion or extraction script for you in python or Pandas and then run it on your own.
#
# In this part of the assignment you will prompt 383GPT to explore these capabilities.

# %% [markdown]
# ## Part 4.1 GPT Data Manipulation
#
# Take the cleaned dataset that you created in part three and output the top 15 rows of that dataset. Then copy the terminal output, open 383gpt and ask it to convert that output to a markdown table. Paste that markdown table in the cell bellow

# %% [markdown]
# Paste here: ```markdown
# |    |       age |    bp |       bgr |        bu |        sc |       sod |       pot |     hemo |       pcv |     wbcc | cad_no | cad_yes | appet_good | appet_poor |   pe_no | pe_yes | ane_no | ane_yes | Target_ckd | Target_notckd |
# |----|-----------|-------|-----------|-----------|-----------|-----------|-----------|-----------|-----------|-----------|--------|---------|------------|-------------|---------|--------|--------|---------|------------|----------------|
# | 2  | 0.743243  |  0.50 | 0.442060  | 0.901961  | 0.432099  | 0.500000  | 0.657143  | 0.172131  | 0.210526  | 0.395161  | False  | True    | False      | True        | False   | True   | False  | True    | True       | False          |
# | 5  | 0.770270  |  1.00 | 0.901288  | 0.163399  | 0.345679  | 0.766667  | 0.171429  | 0.606557  | 0.631579  | 0.443548  | False  | True    | True       | False       | True    | False  | True   | False   | True       | False          |
# | 7  | 0.905405  |  0.50 | 0.785408  | 0.862745  | 0.518519  | 0.600000  | 0.828571  | 0.401639  | 0.447368  | 0.233871  | False  | True    | True       | False       | True    | False  | True   | False   | True       | False          |
# | 8  | 0.202703  |  0.75 | 0.158798  | 0.196078  | 0.160494  | 0.166667  | 0.171429  | 0.221311  | 0.184211  | 0.653226  | True   | False   | True       | False       | True    | False  | False  | True    | True       | False          |
# | 9  | 0.783784  |  1.00 | 0.399142  | 0.287582  | 0.839506  | 0.666667  | 0.485714  | 0.188525  | 0.263158  | 0.258065  | True   | False   | True       | False       | True    | False  | True   | False   | True       | False          |
# | 10 | 0.729730  |  0.00 | 0.935622  | 0.169935  | 0.160494  | 0.333333  | 0.028571  | 0.188525  | 0.236842  | 0.879032  | True   | False   | False      | True        | True    | False  | False  | True    | True       | False          |
# | 12 | 0.675676  |  0.75 | 0.253219  | 0.633987  | 0.777778  | 0.366667  | 0.542857  | 0.286885  | 0.342105  | 0.169355  | True   | False   | True       | False       | True    | False  | True   | False   | True       | False          |
# | 13 | 0.851351  |  0.25 | 0.618026  | 0.562092  | 0.728395  | 0.000000  | 0.285714  | 0.311475  | 0.315789  | 0.580645  | False  | True    | True       | False       | True    | False  | True   | False   | True       | False          |
# | 15 | 0.540541  |  0.00 | 0.399142  | 0.535948  | 0.358025  | 0.700000  | 0.314286  | 0.344262  | 0.315789  | 0.830645  | True   | False   | True       | False       | True    | False  | True   | False   | True       | False          |
# | 18 | 0.756757  |  0.25 | 0.223176  | 0.209150  | 0.160494  | 0.533333  | 0.514286  | 0.573770  | 0.605263  | 0.290323  | True   | False   | True       | False       | True    | False  | True   | False   | True       | False          |
# | 19 | 0.662162  |  0.50 | 0.618026  | 0.411765  | 0.432099  | 0.566667  | 0.571429  | 0.434426  | 0.473684  | 0.250000  | True   | False   | True       | False       | True    | False  | True   | False   | True       | False          |
# | 20 | 0.783784  |  0.00 | 0.725322  | 0.313725  | 0.481481  | 0.566667  | 0.714286  | 0.319672  | 0.342105  | 0.258065  | True   | False   | False      | True        | True    | False  | True   | False   | True       | False          |
# | 22 | 0.878378  |  0.00 | 0.206009  | 0.751634  | 0.604938  | 0.533333  | 0.571429  | 0.475410  | 0.500000  | 0.879032  | True   | False   | False      | True        | True    | False  | True   | False   | True       | False          |
# | 23 | 0.878378  |  0.25 | 0.639485  | 0.470588  | 0.395062  | 0.433333  | 0.428571  | 0.393443  | 0.447368  | 0.104839  | False  | True    | True       | False       | True    | False  | True   | False   | True       | False          |
# | 29 | 0.716216  |  0.50 | 1.000000  | 0.163399  | 0.111111  | 0.066667  | 0.171429  | 0.393443  | 0.500000  | 0.532258  | True   | False   | False      | True        | True    | False  | True   | False   | True       | False          |
# ```

# %% [markdown]
# ** Caution: ** while language models can perform data conversions they also can * hallucinate * during this process, particularly for bigger datasets. Reflect on this below, how could you mitigate data conversion hallucinations from LLM conversions?

# %% [markdown]
# Answer: To mitigate such hallucinations, I would be precise with my prompt and expected output format so that the inputted data isn't ambiguous. I would also segment the data into chunks so that the context window of the LLM isn't overwhelmed with one huge piece. I would also check the outputted data against my origional and feed it back to the LLM to show where it went wrong.

# %% [markdown]
# ## Part 4.2 GPT Pandas Prompting
#
# In this section, you will prompt 383GPT to write pandas code manipulations for you.
#
# After working with this data for awhile, we realized we're starting to forget the meanings of the abbreviated column names. Let's ask 383GPT to fix this for us. First, navigate to the [UCI dataset overview](https://archive.ics.uci.edu/dataset/336/chronic+kidney+disease) and copy the abbrevation to name mapping. Then, go to 383GPT and instruct the LLM to provide you with a pandas script to apply this renaming to all the columns of your dataset. Paste that code below and make any adjustments necessary to run it in your notebook.

# %%
# Code to rename all the columns in the dataset
new_column_names = {
    'age': 'Age',
    'bp': 'Blood Pressure',
    'sg': 'Specific Gravity',
    'al': 'Albumin',
    'su': 'Sugar',
    'rbc': 'Red Blood Cells',
    'pc': 'Pus Cell',
    'pcc': 'Pus Cell Clumps',
    'ba': 'Bacteria',
    'bgr': 'Blood Glucose Random',
    'bu': 'Blood Urea',
    'sc': 'Serum Creatinine',
    'sod': 'Sodium',
    'pot': 'Potassium',
    'hemo': 'Hemoglobin',
    'pcv': 'Packed Cell Volume',
    'wbcc': 'White Blood Cell Count',
    'rbcc': 'Red Blood Cell Count',
    'htn': 'Hypertension',
    'dm': 'Diabetes Mellitus',
    'cad': 'Coronary Artery Disease',
    'appet': 'Appetite',
    'pe': 'Pedal Edema',
    'ane': 'Anemia',
    'class': 'CKD or Not CKD'
}

# Rename the columns
normalized_ds.rename(columns=new_column_names, inplace=True)

# Display the updated DataFrame with new column names
print(normalized_ds)
# Out:
#           Age  Blood Pressure  Blood Glucose Random  Blood Urea  \
# 2    0.743243            0.50              0.442060    0.901961
# 5    0.770270            1.00              0.901288    0.163399
# 7    0.905405            0.50              0.785408    0.862745
# 8    0.202703            0.75              0.158798    0.196078
# 9    0.783784            1.00              0.399142    0.287582
# ..        ...             ...                   ...         ...
# 148  0.189189            0.25              0.227468    0.222222
# 149  0.216216            0.00              0.115880    0.052288
# 150  0.513514            0.00              0.107296    0.235294
# 151  0.702703            0.50              0.128755    0.261438
# 152  0.689189            0.00              0.150215    0.254902
#
#      Serum Creatinine    Sodium  Potassium  Hemoglobin  Packed Cell Volume  \
# 2            0.432099  0.500000   0.657143    0.172131            0.210526
# 5            0.345679  0.766667   0.171429    0.606557            0.631579
# 7            0.518519  0.600000   0.828571    0.401639            0.447368
# 8            0.160494  0.166667   0.171429    0.221311            0.184211
# 9            0.839506  0.666667   0.485714    0.188525            0.263158
# ..                ...       ...        ...         ...                 ...
# 148          0.074074  0.500000   0.257143    0.737705            0.736842
# 149          0.098765  0.600000   0.400000    0.647541            0.684211
# 150          0.012346  0.600000   0.371429    0.770492            0.894737
# 151          0.098765  0.666667   0.171429    0.688525            0.894737
# 152          0.098765  1.000000   0.514286    0.827869            0.736842
#
#      White Blood Cell Count  ...  cad_no  cad_yes  appet_good  appet_poor  \
# 2                  0.395161  ...   False     True       False        True
# 5                  0.443548  ...   False     True        True       False
# 7                  0.233871  ...   False     True        True       False
# 8                  0.653226  ...    True    False        True       False
# 9                  0.258065  ...    True    False        True       False
# ..                      ...  ...     ...      ...         ...         ...
# 148                0.096774  ...    True    False        True       False
# 149                0.290323  ...    True    False        True       False
# 150                0.274194  ...    True    False        True       False
# 151                0.193548  ...    True    False        True       False
# 152                0.491935  ...    True    False        True       False
#
#      pe_no  pe_yes  ane_no  ane_yes  Target_ckd  Target_notckd
# 2    False    True   False     True        True          False
# 5     True   False    True    False        True          False
# 7     True   False    True    False        True          False
# 8     True   False   False     True        True          False
# 9    False    True    True    False        True          False
# ..     ...     ...     ...      ...         ...            ...
# 148   True   False    True    False       False           True
# 149   True   False    True    False       False           True
# 150   True   False    True    False       False           True
# 151   True   False    True    False       False           True
# 152   True   False    True    False       False           True
#
# [134 rows x 35 columns]

# %% [markdown]
# ## Part 4.3 Augmenting our skills with prompting
#
# In addition, we can also use 383GPT to convert our data manipulation operations between different data manipulation languages and libraries. For example let's prompt 383GPT to convert the following SQL query to a pandas query.
#
# **SQL Query**
# ```sql
# SELECT Target, COUNT(*) AS count
# FROM your_table_name
# GROUP BY Target;
# ```
#
# Prompt 383GPT to convert this to a pandas query. Run this query below, then describe what it does. (If you're not familiar with SQL that is okay you need to only comment on the final resulting output.)

# %%
# Converted SQL to Pandas code
# Group by 'Target' and count occurrences
result = normalized_ds.groupby('Target_ckd').size().reset_index(name='count')

# Display the result
print(result)
# Out:
#    Target_ckd  count
# 0       False    111
# 1        True     23

# %% [markdown]
# The above code looks at the "Target" column in my dataset (Earlier steps made me change the name of Target to Target_ckd, but the data is the same) and then counts the values present in the column. For this column, the values are either True or False, and the output above shows the amount of each in that column.
